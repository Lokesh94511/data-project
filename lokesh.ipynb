# %% [markdown]
# <a href="https://colab.research.google.com/github/Lokesh94511/data-project/blob/main/lokesh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#dictionary
datal={
    'Name':['jai','princi','gaurav','anu'],
       'Age':[21,24,32,22],
       'Adress':['nagpur','kanpur','allahabad','marella'],
       'qualification':['Msc','MA','Mca','phd']
       }
data2={
    'Name':['Loki','Lokesh','Krishna','Mano'],
       'Age':[21,24,32,22],
       'Adress':['Kandukur','kanpur','allahabad','marella'],
       'qualification':['b.tech','B.A','Mca','phd']
       }
#convert the dictionary into dataframes
df=pd.DataFrame(datal,index=[0,1,2,3])

df1=pd.DataFrame(data2,index=[4,5,6,7])

print(df,"\n\n",df1)

frames=(df,df1)

res1=pd.concat(frames)
res1
# Out:
#      Name  Age     Adress qualification
# 0     jai   21     nagpur           Msc
# 1  princi   24     kanpur            MA
# 2  gaurav   32  allahabad           Mca
# 3     anu   22    marella           phd
#
#        Name  Age     Adress qualification
# 4     Loki   21   Kandukur        b.tech
# 5   Lokesh   24     kanpur           B.A
# 6  Krishna   32  allahabad           Mca
# 7     Mano   22    marella           phd
#       Name  Age     Adress qualification
# 0      jai   21     nagpur           Msc
# 1   princi   24     kanpur            MA
# 2   gaurav   32  allahabad           Mca
# 3      anu   22    marella           phd
# 4     Loki   21   Kandukur        b.tech
# 5   Lokesh   24     kanpur           B.A
# 6  Krishna   32  allahabad           Mca
# 7     Mano   22    marella           phd

# %%
import pandas as pd
datal={'Name':['jai','princi','gaurav','anu'],
       'Age':[21,24,32,22],
       'Adress':['nagpur','kanpur','allahabad','marella'],
       'qualification':['Msc','MA','Mca','phd'] }
data2={'Name':['Loki','Lokesh','Krishna','Mano'],
       'Age':[21,24,32,22],
       'Adress':['Kandukur','kanpur','allahabad','marella'],
       'qualification':['b.tech','B.A','Mca','phd']}
#convert the dictionary into dataframes
df = pd.DataFrame(datal,index=[0,1,2,3])

df1 = pd.DataFrame(data2,index=[2,3,6,7])

print(df,"\n\n",df1)
# applying concat with axes
# join = 'inner'w
res2 = pd.concat([df, df1], axis=1, join='inner')

res2
# Out:
#      Name  Age     Adress qualification
# 0     jai   21     nagpur           Msc
# 1  princi   24     kanpur            MA
# 2  gaurav   32  allahabad           Mca
# 3     anu   22    marella           phd
#
#        Name  Age     Adress qualification
# 2     Loki   21   Kandukur        b.tech
# 3   Lokesh   24     kanpur           B.A
# 6  Krishna   32  allahabad           Mca
# 7     Mano   22    marella           phd
#      Name  Age     Adress qualification    Name  Age    Adress qualification
# 2  gaurav   32  allahabad           Mca    Loki   21  Kandukur        b.tech
# 3     anu   22    marella           phd  Lokesh   24    kanpur           B.A

# %%
import pandas as pd
datal={'Name':['jai','princi','gaurav','anu'],
       'Age':[21,24,32,22],
       'Adress':['nagpur','kanpur','allahabad','marella'],
       'qualification':['Msc','MA','Mca','phd'] }
data2={'Name':['Loki','Lokesh','Krishna','Mano'],
       'Age':[21,24,32,22],
       'Adress':['Kandukur','kanpur','allahabad','marella'],
       'qualification':['b.tech','B.A','Mca','phd']}
#convert the dictionary into dataframes
df = pd.DataFrame(datal,index=[0,1,2,3])

df1 = pd.DataFrame(data2,index=[2,3,6,7])

print(df,"\n\n",df1)
#using a concat for
# union of dataframe-outer
res2 = pd.concat([df, df1], axis=1, sort=False)

res2
# Out:
#      Name  Age     Adress qualification
# 0     jai   21     nagpur           Msc
# 1  princi   24     kanpur            MA
# 2  gaurav   32  allahabad           Mca
# 3     anu   22    marella           phd
#
#        Name  Age     Adress qualification
# 2     Loki   21   Kandukur        b.tech
# 3   Lokesh   24     kanpur           B.A
# 6  Krishna   32  allahabad           Mca
# 7     Mano   22    marella           phd
#      Name   Age     Adress qualification     Name   Age     Adress  \
# 0     jai  21.0     nagpur           Msc      NaN   NaN        NaN
# 1  princi  24.0     kanpur            MA      NaN   NaN        NaN
# 2  gaurav  32.0  allahabad           Mca     Loki  21.0   Kandukur
# 3     anu  22.0    marella           phd   Lokesh  24.0     kanpur
# 6     NaN   NaN        NaN           NaN  Krishna  32.0  allahabad
# 7     NaN   NaN        NaN           NaN     Mano  22.0    marella
#
#   qualification
# 0           NaN
# 1           NaN
# 2        b.tech
# ...

# %%
import pandas as pd
datal={'Name':['jai','princi','gaurav','anu'],
       'Age':[21,24,32,22],
       'Adress':['nagpur','kanpur','allahabad','marella'],
       'qualification':['Msc','MA','Mca','phd'] }
data2={'Name':['Loki','Lokesh','Krishna','Mano'],
       'Age':[21,24,32,22],
       'Adress':['Kandukur','kanpur','allahabad','marella'],
       'qualification':['b.tech','B.A','Mca','phd']}
#convert the dictionary into dataframes
df = pd.DataFrame(datal,index=[0,1,2,3])

df1 = pd.DataFrame(data2,index=[2,3,6,7])

print(df,"\n\n",df1)
#using ignore_index
res2 = pd.concat([df, df1],ignore_index =True)

res2
# Out:
#      Name  Age     Adress qualification
# 0     jai   21     nagpur           Msc
# 1  princi   24     kanpur            MA
# 2  gaurav   32  allahabad           Mca
# 3     anu   22    marella           phd
#
#        Name  Age     Adress qualification
# 2     Loki   21   Kandukur        b.tech
# 3   Lokesh   24     kanpur           B.A
# 6  Krishna   32  allahabad           Mca
# 7     Mano   22    marella           phd
#       Name  Age     Adress qualification
# 0      jai   21     nagpur           Msc
# 1   princi   24     kanpur            MA
# 2   gaurav   32  allahabad           Mca
# 3      anu   22    marella           phd
# 4     Loki   21   Kandukur        b.tech
# 5   Lokesh   24     kanpur           B.A
# 6  Krishna   32  allahabad           Mca
# 7     Mano   22    marella           phd

# %%
import pandas as pd
datal={'Name':['jai','princi','gaurav','anu'],
       'Age':[21,24,32,22],
       'Adress':['nagpur','kanpur','allahabad','marella'],
       'qualification':['Msc','MA','Mca','phd'] }

#convert the dictionary into dataframes
df = pd.DataFrame(datal,index=[0,1,2,3])
#creating a series
s1 = pd.Series([1000, 2000, 3000, 4000], name='Salary')
print(df,"\n\n",s1)
#concat
res = pd.concat([df, s1], axis=1)

res
# Out:
#      Name  Age     Adress qualification
# 0     jai   21     nagpur           Msc
# 1  princi   24     kanpur            MA
# 2  gaurav   32  allahabad           Mca
# 3     anu   22    marella           phd
#
#  0    1000
# 1    2000
# 2    3000
# 3    4000
# Name: Salary, dtype: int64
#      Name  Age     Adress qualification  Salary
# 0     jai   21     nagpur           Msc    1000
# 1  princi   24     kanpur            MA    2000
# 2  gaurav   32  allahabad           Mca    3000
# 3     anu   22    marella           phd    4000

# %%
import pandas as pd
data1={'key':['k0','k1','k2','k3'],
       'Name':['jai','princi','gaurav','anu'],
       'Age':[21,24,32,22]}
data2={'key':['k0','k1','k2','k3'],
       'Adress':['nagpur','kanpur','allahabad','marella'],
       'qualification':['Msc','MA','Mca','phd']}

df =pd.DataFrame(data1)
df1=pd.DataFrame(data2)
res=pd.merge(df,df1,on='key')
res
# Out:
#   key    Name  Age     Adress qualification
# 0  k0     jai   21     nagpur           Msc
# 1  k1  princi   24     kanpur            MA
# 2  k2  gaurav   32  allahabad           Mca
# 3  k3     anu   22    marella           phd

# %%
import pandas as pd
data1={'key':['k0', 'k1','k2','k3'], # Fixed the typo here
       'Name':['jai','princi','gaurav','anu'],
       'Age':[21,24,32,22]}
data2={'key':['k0','k1','k2','k3'],
       'Adress':['nagpur','kanpur','allahabad','marella'],
       'qualification':['Msc','MA','Mca','phd']}

df =pd.DataFrame(data1)
df1=pd.DataFrame(data2)
res=pd.merge(df,df1,on='key')
res
# Out:
#   key    Name  Age     Adress qualification
# 0  k0     jai   21     nagpur           Msc
# 1  k1  princi   24     kanpur            MA
# 2  k2  gaurav   32  allahabad           Mca
# 3  k3     anu   22    marella           phd

# %%
import pandas as pd
data1={'key':['k0','k1','k2','k3'],
       'key1':['k0','k1','k0','k1'],
       'Name':['jai','princi','gaurav','anu'],
       'Age':[21,24,32,22]}
data2={'key':['k0','k1','k2','k3'],
       'key1':['k0','k0','k0','k0'],
       'Adress':['nagpur','kanpur','allahabad','marella'],
       'qualification':['Msc','MA','Mca','phd']}

df =pd.DataFrame(data1)
df1=pd.DataFrame(data2)
res1=pd.merge(df,df1,on=['key','key1'])
res1
# Out:
#   key key1    Name  Age     Adress qualification
# 0  k0   k0     jai   21     nagpur           Msc
# 1  k2   k0  gaurav   32  allahabad           Mca
